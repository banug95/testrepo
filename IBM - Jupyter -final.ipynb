# %% [markdown]
# # My Jupyter Notebook on IBM Watson Studio

# %% [markdown]
# **BANU G**
# Desired Occupation : Data Scientist

# %% [markdown]
# *I am Interested in Data science because in market research it helps us discover customer needs and provide quality service to them as well as enable businesses to boom.*

# %% [markdown]
# ### The Code below Stores two values in two seperate variables. We are adding them and storing the result in a third variable. The Third variable value is displayed to the user

# %%
a = 1
b = 2
c = a + b
c
# Out:
# 3

# %% [markdown]
# **Values in the Above Code**
# ***
# |Variable|Value|Input or Output|
# | ------------- |:-------------:| -----:|
# | a | 1 | input |
# | b | 2 | input |
# | c | 3 | output |
#
# **List of variables in the Above Code**
#
# 1. a
# 2. b
# 3. c
